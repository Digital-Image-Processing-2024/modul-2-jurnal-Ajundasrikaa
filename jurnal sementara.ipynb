# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import pandas as pd

# %%
image = plt.imread("senheScramble.jpg")
plt.imshow(image)

# %%
image = cv.imread("senheScramble.jpg")
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.imshow(gray_image, cmap='gray')
plt.show()
